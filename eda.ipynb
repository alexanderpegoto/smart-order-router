# %%
import pandas as pd
import numpy as np

# %%
l1 = pd.read_csv('l1_day.csv')

# %%
l1.head()
# Out:
#                           ts_recv                        ts_event  rtype  \
# 0  2024-08-01T13:36:32.492082308Z  2024-08-01T13:36:32.491911683Z     10
# 1  2024-08-01T13:36:32.492082308Z  2024-08-01T13:36:32.491911683Z     10
# 2  2024-08-01T13:36:32.492082308Z  2024-08-01T13:36:32.491911683Z     10
# 3  2024-08-01T13:36:32.492082308Z  2024-08-01T13:36:32.491911683Z     10
# 4  2024-08-01T13:36:32.492082308Z  2024-08-01T13:36:32.491912675Z     10
#
#    publisher_id  instrument_id action side  depth   price  size  ...  \
# 0             2             38      T    A      0  222.81   190  ...
# 1             2             38      T    A      0  222.81    10  ...
# 2             2             38      T    A      0  222.81   100  ...
# 3             2             38      T    A      0  222.81   121  ...
# 4             2             38      A    N      0  222.83    10  ...
#
#    ask_sz_08  bid_ct_08  ask_ct_08  bid_px_09  ask_px_09  bid_sz_09  \
# ...

# %%
l1.publisher_id.value_counts()
# Out:
# publisher_id
# 2    59999
# Name: count, dtype: int64

# %%
l1.shape
# Out:
# (59999, 74)

# %%
clean_df =l1.drop_duplicates(subset=['ts_event','publisher_id'], keep='first').sort_values(by='ts_event', ascending=True)

clean_df.head()
# Out:
#                           ts_recv                        ts_event  rtype  \
# 0  2024-08-01T13:36:32.492082308Z  2024-08-01T13:36:32.491911683Z     10
# 4  2024-08-01T13:36:32.492082308Z  2024-08-01T13:36:32.491912675Z     10
# 5  2024-08-01T13:36:32.492093947Z  2024-08-01T13:36:32.491927912Z     10
# 6  2024-08-01T13:36:32.492105645Z  2024-08-01T13:36:32.491939846Z     10
# 7  2024-08-01T13:36:32.492110610Z  2024-08-01T13:36:32.491944432Z     10
#
#    publisher_id  instrument_id action side  depth   price  size  ...  \
# 0             2             38      T    A      0  222.81   190  ...
# 4             2             38      A    N      0  222.83    10  ...
# 5             2             38      A    A      0  222.83   100  ...
# 6             2             38      A    A      0  222.82    87  ...
# 7             2             38      A    B      1  222.79   100  ...
#
#    ask_sz_08  bid_ct_08  ask_ct_08  bid_px_09  ask_px_09  bid_sz_09  \
# ...

# %%
len(clean_df.publisher_id.unique())
# Out:
# 1

# %%
def optimal_order_allocation(df,l,lambda_under, lambda_over, S, Q, theta):
    if len(df.publisher_id.unique()) == 1:
        if l >= lambda_under:
# Out:
#   Cell In[25], line 4
#
#     ^
# SyntaxError: incomplete input
